# %%
import pathlib
import re

import geopandas as gpd
import pandas as pd

# %%
data_dir = pathlib.Path('~/data/euris').expanduser()
version = 'v0.1.0'

# %%
node_paths = list(data_dir.glob('Node_*.geojson'))
sections_paths = list(data_dir.glob('FairwaySection_*.geojson'))

node_path_re = re.compile(r'Node_(?P<countrycode>[A-Z]+)_\d+.geojson')
sections_path_re = re.compile(r'FairwaySection_(?P<countrycode>[A-Z]+)_\d+.geojson')

# %%
node_gdfs = []
for node_path in node_paths:
    node_gdf = gpd.read_file(node_path)
    # add file that data came from (includes version)
    node_gdf['path'] = node_path.name
    node_gdfs.append(node_gdf)
node_gdf = pd.concat(node_gdfs)

# %%
section_gdfs = []
for section_path in sections_paths:
    section_gdf = gpd.read_file(section_path)
    # add file that data came from (includes version)
    section_gdf['path'] = section_path.name
    section_gdfs.append(section_gdf)
section_gdf = pd.concat(section_gdfs)
# Out:
# /var/folders/gr/0j917nfx62x487fv_l35dkn40000gn/T/ipykernel_70596/815172192.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   section_gdf = pd.concat(section_gdfs)

# %%
uniq_columns = set(node_gdf.columns) - {'path'}
n_nodes_duplicated = node_gdf.duplicated(subset=uniq_columns).sum()
node_gdf = node_gdf.drop_duplicates(subset=uniq_columns)
uniq_columns = set(section_gdf.columns) - {'path'}
n_sections_duplicated = section_gdf.duplicated(subset=uniq_columns).sum()
section_gdf = section_gdf.drop_duplicates(subset=uniq_columns)
print(f'removed {n_nodes_duplicated} duplicated nodes, {n_sections_duplicated} duplicated sections.')




node_gdf['countrycode_locode'] = node_gdf['locode'].apply(
    lambda x: x[:2]
)
node_gdf['countrycode_path'] = node_gdf['path'].apply(
    lambda x: node_path_re.match(x).group('countrycode')
)
node_gdf['countrycode'] = node_gdf['countrycode_locode']

node_gdf['node_id'] = node_gdf.apply(lambda row: f"{row['countrycode']}_{row['objectcode']}", axis=1)
# Out:
# removed 291 duplicated nodes, 135 duplicated sections.

# %%
node_gdf.to_file(data_dir / f'nodes-{version}.geojson')
section_gdf.to_file(data_dir / f'sections-{version}.geojson')

# %%
node_gdf.shape[0], section_gdf.shape[0] * 2
# Out:
# (13472, 13478)

# %%
node_gdf[node_gdf['countrycode_locode'] != node_gdf['countrycode_path']]
# Out:
#    objectcode_cb hectom_cb sectionref_cb             locode_cb  function  \
# 0          J0023     22018  AT0000100002  ATXXX00001J002322014  junction
# 1          J0099     22232  AT0000100001  ATXXX00001J009922231  junction
# 2          J0098     22031  AT0000100001  ATXXX00001J009822031  junction
# 3          J0098     22031  AT0000100002  ATXXX00001J009822031  junction
# 4          J0010     18802  AT0000100033  ATXXX00001J001018802  junction
# ..           ...       ...           ...                   ...       ...
# 3          N1683     00618  FRVN21900005  FRXXXVN219LOCKS00618  junction
# 4          N1683     00618  FRVN21900006  FRXXXVN219LOCKS00618  junction
# 5          N1684     00625  FRVN21900006  FRXXXVN2190000000625  junction
# 6          N1684     00625  FRVN21900007  FRXXXVN2190000000625  junction
# 7          N1536     00637  FRVN21900007  FRXXXVN219J015600637  junction
#
#       ww_name ww_name_cb    rt_name rt_name_cb              wwauthorit  ...  \
# 0       Donau      Donau       None      Donau                     WSV  ...
# 1       Donau      Donau       None      Donau                     WSV  ...
# 2       Donau      Donau       None      Donau                     WSV  ...
# 3       Donau      Donau       None      Donau                     WSV  ...
# 4       Dunaj      Donau      Dunaj      Donau           Dopravný úrad  ...
# ..        ...        ...        ...        ...                     ...  ...
# 3   Grensleie        Lys  Grensleie        Lys  De Vlaamse Waterweg nv  ...
# 4   Grensleie        Lys  Grensleie        Lys  De Vlaamse Waterweg nv  ...
# 5   Grensleie        Lys  Grensleie        Lys  De Vlaamse Waterweg nv  ...
# 6   Grensleie        Lys  Grensleie        Lys  De Vlaamse Waterweg nv  ...
# 7   Grensleie        Lys  Grensleie        Lys  De Vlaamse Waterweg nv  ...
#
#                              objectname    sectionref hectom vplnpoint  \
# 0                  DEXXX00401J006022018  DE0040100659  22018       1.0
# 1                  DEXXX00401J282122232  DE0040100383  22232       NaN
# 2                  DEXXX00401J287222031  DE0040100383  22031       NaN
# 3                  DEXXX00401J287222031  DE0040100659  22031       NaN
# 4   Ústie Moravy - Štátna hranica AT-SK  SK0000100001  18802       1.0
# ..                                  ...           ...    ...       ...
# 3                  BEMEN18510F190800150  BE1851000000  00150       1.0
# 4                  BEMEN18511F190800150  BE1851100000  00150       1.0
# 5                  BEMEN18511F194700157  BE1851100000  00157       1.0
# 6                  BEMEN18512F194700157  BE1851200000  00157       1.0
# 7                  BEMEN18512F199200168  BE1851200000  00168       0.0
#
#                      geometry                      path countrycode_locode  \
# 0     POINT (13.727 48.51292)  Node_AT_20250512.geojson                 DE
# 1   POINT (13.50104 48.58098)  Node_AT_20250512.geojson                 DE
# 2   POINT (13.71066 48.51825)  Node_AT_20250512.geojson                 DE
# 3   POINT (13.71066 48.51825)  Node_AT_20250512.geojson                 DE
# 4    POINT (16.97613 48.1722)  Node_AT_20250512.geojson                 SK
# ..                        ...                       ...                ...
# 3    POINT (3.10208 50.78134)  Node_FR_20241106.geojson                 BE
# 4    POINT (3.10208 50.78134)  Node_FR_20241106.geojson                 BE
# 5    POINT (3.10772 50.78534)  Node_FR_20241106.geojson                 BE
# 6    POINT (3.10772 50.78534)  Node_FR_20241106.geojson                 BE
# 7    POINT (3.12225 50.78998)  Node_FR_20241106.geojson                 BE
#
#    countrycode_path  countrycode   node_id
# 0                AT           DE  DE_J0060
# 1                AT           DE  DE_J2821
# 2                AT           DE  DE_J2872
# 3                AT           DE  DE_J2872
# 4                AT           SK  SK_J0001
# ..              ...          ...       ...
# 3                FR           BE  BE_F1908
# 4                FR           BE  BE_F1908
# 5                FR           BE  BE_F1947
# 6                FR           BE  BE_F1947
# 7                FR           BE  BE_F1992
#
# [122 rows x 25 columns]
