# %%
import pathlib
import re

import geopandas as gpd
import pandas as pd

# %%
data_dir = pathlib.Path('~/data/euris').expanduser()
version = 'v0.1.0'

# %%
node_paths = list(data_dir.glob('Node_*.geojson'))
sections_paths = list(data_dir.glob('FairwaySection_*.geojson'))

node_path_re = re.compile(r'Node_(?P<countrycode>[A-Z]+)_\d+.geojson')
sections_path_re = re.compile(r'FairwaySection_(?P<countrycode>[A-Z]+)_\d+.geojson')

# %%
node_gdfs = []
for node_path in node_paths:
    node_gdf = gpd.read_file(node_path)
    # add file that data came from (includes version)
    node_gdf['path'] = node_path.name
    node_gdfs.append(node_gdf)
node_gdf = pd.concat(node_gdfs)

# %%
section_gdfs = []
for section_path in sections_paths:
    section_gdf = gpd.read_file(section_path)
    # add file that data came from (includes version)
    section_gdf['path'] = section_path.name
    section_gdfs.append(section_gdf)
section_gdf = pd.concat(section_gdfs)
# Out:
# /tmp/ipykernel_3011465/815172192.py:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   section_gdf = pd.concat(section_gdfs)

# %%
uniq_columns = set(node_gdf.columns) - {'path'}
n_nodes_duplicated = node_gdf.duplicated(subset=uniq_columns).sum()
node_gdf = node_gdf.drop_duplicates(subset=uniq_columns)
uniq_columns = set(section_gdf.columns) - {'path'}
n_sections_duplicated = section_gdf.duplicated(subset=uniq_columns).sum()
section_gdf = section_gdf.drop_duplicates(subset=uniq_columns)
print(f'removed {n_nodes_duplicated} duplicated nodes, {n_sections_duplicated} duplicated sections.')




node_gdf['countrycode_locode'] = node_gdf['locode'].apply(
    lambda x: x[:2]
)
node_gdf['countrycode_path'] = node_gdf['path'].apply(
    lambda x: node_path_re.match(x).group('countrycode')
)
node_gdf['countrycode'] = node_gdf['countrycode_locode']

node_gdf['node_id'] = node_gdf.apply(lambda row: f"{row['countrycode']}_{row['objectcode']}", axis=1)

# TODO: add columns with section_id (for consistent naming)
# Out:
# removed 291 duplicated nodes, 138 duplicated sections.

# %%
node_gdf.to_file(data_dir / f'nodes-{version}.geojson')
section_gdf.to_file(data_dir / f'sections-{version}.geojson')

# %%
node_gdf.shape[0], section_gdf.shape[0] * 2
# Out:
# (13592, 13592)

# %%
node_gdf[node_gdf['countrycode_locode'] != node_gdf['countrycode_path']]
# Out:
#      objectcode_cb hectom_cb sectionref_cb             locode_cb  function  \
# 0             None     00056  NL0150C00530  NLSVW0150CJ352400056  junction
# 1             None     00059  NL0150C00530  NLSVW0150CJ696500059  junction
# 2             None     00059  NL0150C00000  NLSVW0150CJ696500059  junction
# 3             None     00111  NL0150C00000  NLSVW0150CJ245100111  junction
# 4             None     00046  NL0150C00564  NLMSB0150CJ477000046  junction
# ...            ...       ...           ...                   ...       ...
# 1252         J3356     03137  DE0390100735  DEXXX03901J335603137  junction
# 1253         J3356     03137  DE0390100736  DEXXX03901J335603137  junction
# 1254         J3355     03319  DE0390100736  DEXXX03901J335503319  junction
# 1255         J3355     03319  DE0390100737  DEXXX03901J335503319  junction
# 1256         J2625     03340  DE0390100737  DEXXX03901J262503340  junction
#
#                       ww_name ww_name_cb                  rt_name  \
# 0     Gemeenschappelijke Maas       Maas  Gemeenschappelijke Maas
# 1     Gemeenschappelijke Maas       Maas  Gemeenschappelijke Maas
# 2     Gemeenschappelijke Maas       Maas  Gemeenschappelijke Maas
# 3     Gemeenschappelijke Maas       Maas  Gemeenschappelijke Maas
# 4     Gemeenschappelijke Maas       Maas  Gemeenschappelijke Maas
# ...                       ...        ...                      ...
# 1252                     Rhin      Rhein            Rhin canalise
# 1253                     Rhin      Rhein            Rhin canalise
# 1254                     Rhin      Rhein            Rhin canalise
# 1255                     Rhin      Rhein            Rhin canalise
# 1256                     Rhin      Rhein            Rhin canalise
#
#                             rt_name_cb              wwauthorit  ...  \
# 0     Maas van Wessem naar Ohe en Laak  De Vlaamse Waterweg nv  ...
# 1     Maas van Wessem naar Ohe en Laak  De Vlaamse Waterweg nv  ...
# 2     Maas van Wessem naar Ohe en Laak  De Vlaamse Waterweg nv  ...
# 3     Maas van Wessem naar Ohe en Laak  De Vlaamse Waterweg nv  ...
# 4     Maas van Wessem naar Ohe en Laak  De Vlaamse Waterweg nv  ...
# ...                                ...                     ...  ...
# 1252                             Rhein                     VNF  ...
# 1253                             Rhein                     VNF  ...
# 1254                             Rhein                     VNF  ...
# 1255                             Rhein                     VNF  ...
# 1256                             Rhein                     VNF  ...
#
#                                              objectname    sectionref hectom  \
# 0                               Jachthaven Stevensweert  BE0440400000  00624
# 1                        Aansluiting Grensmaas Visakker  BE0440400000  00620
# 2                        Aansluiting Grensmaas Visakker  BE0440300000  00620
# 3                                  BEMSK04403F556900568  BE0440300000  00568
# 4     Grenspunt Kinrooi Gemeenschappelijke Maas (Ned...  BE0440500000  00636
# ...                                                 ...           ...    ...
# 1252        Rhin canalise - Port autonome de Strasbourg  FRVN25300038   3137
# 1253        Rhin canalise - Port autonome de Strasbourg  FRVN25300039   3137
# 1254                               FRXXXVN2530000003319  FRVN25300039   3319
# 1255                               FRXXXVN2530000003319  FRVN25300040   3319
# 1256          Chute d'Iffezheim - Bief aval d'Iffezheim  FRVN25300040   3340
#
#      vplnpoint                  geometry                      path  \
# 0          0.0   POINT (5.8444 51.13834)  Node_NL_20250521.geojson
# 1          0.0  POINT (5.84338 51.13535)  Node_NL_20250521.geojson
# 2          0.0  POINT (5.84338 51.13535)  Node_NL_20250521.geojson
# 3          1.0  POINT (5.82349 51.10814)  Node_NL_20250521.geojson
# 4          1.0   POINT (5.85573 51.1446)  Node_NL_20250521.geojson
# ...        ...                       ...                       ...
# 1252       0.0   POINT (7.9562 48.71581)  Node_DE_20250616.geojson
# 1253       0.0   POINT (7.9562 48.71581)  Node_DE_20250616.geojson
# 1254       0.0  POINT (8.10109 48.81525)  Node_DE_20250616.geojson
# 1255       0.0  POINT (8.10109 48.81525)  Node_DE_20250616.geojson
# 1256       0.0  POINT (8.11349 48.83244)  Node_DE_20250616.geojson
#
#      countrycode_locode countrycode_path  countrycode   node_id
# 0                    BE               NL           BE  BE_F5570
# 1                    BE               NL           BE  BE_F5569
# 2                    BE               NL           BE  BE_F5569
# 3                    BE               NL           BE  BE_F5199
# 4                    BE               NL           BE  BE_F5572
# ...                 ...              ...          ...       ...
# 1252                 FR               DE           FR  FR_J1228
# 1253                 FR               DE           FR  FR_J1228
# 1254                 FR               DE           FR  FR_N3208
# 1255                 FR               DE           FR  FR_N3208
# 1256                 FR               DE           FR  FR_J0663
#
# [102 rows x 25 columns]
