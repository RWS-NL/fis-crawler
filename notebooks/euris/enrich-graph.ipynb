# %%
import pickle
import pathlib

# %%
data_dir = pathlib.Path('~/data/euris').expanduser()

version = 'v0.1.0'
export_pickle_path = data_dir / f'export-graph-{version}.pickle'

# %%
with export_pickle_path.open('rb') as f:
    graph = pickle.load(f)

# %%
# Out:
# 6223
